# %%
from sklearn import datasets
import pydotplus
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn import cross_validation as cv

# %%
iris = datasets.load_iris()
X_train, X_test, Y_train, Y_test = cv.train_test_split(iris.data, iris.target, test_size=0.2)
clf = DecisionTreeClassifier()
clf.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# Now we shall export a decision tree in DOT format
# <br>
# <font color=red>export_graphviz</font> function generates a GraphViz representation of the decision tree, which is then written into out_file specified
# <br>
# The decision tree to be exported is represented by object clf
# <br>
# <font color=red>pydotplus.graph_from_dot_data</font> function loads the graph as defined by a DOT file
# <br>
# last line displays the image

# %%
#Printing the decision tree formed using pydotplus
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data, feature_names = iris.feature_names,class_names = iris.target_names, filled=True, rounded=True, special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
clf.score(X_test, Y_test)
# Out:
# 0.9666666666666667
